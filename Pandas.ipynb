# %%
import pandas as pd   ##importing neccesary libraries
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive #mounting the google drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Reading CSV

# %%
df=pd.read_csv('/content/drive/MyDrive/Ex_Files_Pandas_EssT/Ex_Files_Pandas_EssT/ExerciseFiles/data/olympics.csv',skiprows=4)   ##reading the csv

# %%
print(type(df)) ##checking the type of df
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Checking number of rows and columns

# %%
df.shape   ##checking the number of rows and columns
# Out:
# (29216, 10)

# %%
df.shape[0] ##for just extracting number of rows
# Out:
# 29216

# %%
df.shape[1] ## for just extracting number of columns
# Out:
# 10

# %% [markdown]
# ## Head and tail

# %%
df.head(2) ## n is number of rows you want to extract , if you dont provide value for n it defaults to n=5
# Out:
#      City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming  HERSCHMANN, Otto  AUT    Men
#
#             Event Event_gender   Medal
# 0  100m freestyle            M    Gold
# 1  100m freestyle            M  Silver

# %%
df.tail(2)
# Out:
#           City  Edition      Sport       Discipline         Athlete  NOC  \
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R   LOPEZ, Mijain  CUB
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS
#
#       Gender       Event Event_gender   Medal
# 29214    Men  96 - 120kg            M    Gold
# 29215    Men  96 - 120kg            M  Silver

# %% [markdown]
# ## summary of dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# ## basic analysis

# %% [markdown]
# # Value Counts

# %%
df.Edition.value_counts(sort=False)
# Out:
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# Name: Edition, dtype: int64

# %%
df.Edition.value_counts(sort=True,dropna=False)
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
df.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
df.Athlete.sort_values(ascending=False)
# Out:
# 8051           ÖSTRAND, Per-Olof
# 621                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 603                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
#                   ...
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 651                 AABYE, Edgar
# Name: Athlete, Length: 29216, dtype: object

# %%
df.sort_values(by=["Athlete",'Gender'],ascending=(False,True))
# Out:
#           City  Edition       Sport   Discipline                   Athlete  \
# 8051  Helsinki     1952    Aquatics     Swimming         ÖSTRAND, Per-Olof
# 596      Paris     1900    Shooting     Shooting                ÖSTMO, Ole
# 603      Paris     1900    Shooting     Shooting                ÖSTMO, Ole
# 608      Paris     1900    Shooting     Shooting                ÖSTMO, Ole
# 621      Paris     1900    Shooting     Shooting                ÖSTMO, Ole
# ...        ...      ...         ...          ...                       ...
# 7773    London     1948  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 8563  Helsinki     1952  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 2849   Antwerp     1920    Aquatics     Swimming     AALTONEN, Arvo Ossian
# 2852   Antwerp     1920    Aquatics     Swimming     AALTONEN, Arvo Ossian
# 651      Paris     1900  Tug of War   Tug of War              AABYE, Edgar
#
#       NOC Gender                          Event Event_gender   Medal
# ...

# %%
df[(df["Medal"]=='Gold') & (df['Gender']=='Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %%
df.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
df[df['Athlete'].str.contains('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
df.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
df[ (df['Sport']=='Badminton')& (df['Gender']=='Women')].sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 25738     Athens     2004  Badminton  Badminton              AUDINA, Mia  NED
# 21791    Atlanta     1996  Badminton  Badminton              AUDINA, Mia  INA
# 21790    Atlanta     1996  Badminton  Badminton           BANG, Soo-Hyun  KOR
# 20050  Barcelona     1992  Badminton  Badminton           BANG, Soo-Hyun  KOR
# 20039  Barcelona     1992  Badminton  Badminton          CHUNG, So-Young  KOR
# 27734    Beijing     2008  Badminton  Badminton                 DU, Jing  CHN
# 25732     Athens     2004  Badminton  Badminton               EMMS, Gail  GBR
# 23712     Sydney     2000  Badminton  Badminton                GAO, Ling  CHN
# 25730     Athens     2004  Badminton  Badminton                GAO, Ling  CHN
# 25729     Athens     2004  Badminton  Badminton                GAO, Ling  CHN
# 23707     Sydney     2000  Badminton  Badminton                GAO, Ling  CHN
# ...

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df[df['Edition']>1984].value_counts(df['NOC']).nlargest(3)
# Out:
# NOC
# USA    1504
# AUS     712
# GER     691
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Sport'][df['Edition']==1896].value_counts().plot(kind='line')

# %%
df['Sport'][df['Edition']==1896].value_counts().plot(kind='bar')

# %%
df['Sport'][df['Edition']==1896].value_counts().plot(kind='pie')

# %%
df['Sport'][df['Edition']==1896].value_counts().plot(kind='bar',color='red')

# %%
df['Sport'][df['Edition']==1896].value_counts().plot(kind='bar',color='green',figsize=(10,4))

# %%
import seaborn as sns

# %%
sns.countplot(x='Medal',data=df,hue='Gender')

# %%
df['Gender'][df['NOC']=='CHN'].value_counts().plot(kind='bar')

# %%
sns.countplot(x='Gender' data=df['Edition'])
